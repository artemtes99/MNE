# %%
# %matplotlib notebook
# %matplotlib widget
# %matplotlib inline

import matplotlib.pyplot as plt
import mne

fname = 'oddball-epo.fif'

epochs = mne.read_epochs(fname)
# Out:
# Warning: Cannot change to a different GUI toolkit: widget. Using notebook instead.
# Reading C:\Users\artem\Desktop\Project_practicum\oddball-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 212 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
epochs
# Out:
# <EpochsFIF |  212 events (all good), -0.2 - 0.5 sec, baseline -0.2 – 0 sec, ~7.4 MB, data loaded,
#  'standard/stimulus': 106
#  'target/stimulus': 106>

# %%
epochs.get_data().shape
# Out:
# (212, 64, 71)

# %%
target = epochs['target'].average()
target
# Out:
# <Evoked | 'target/stimulus' (average, N=106), -0.2 – 0.5 sec, baseline -0.2 – 0 sec, 63 ch, ~102 kB>

# %%
standard = epochs['standard'].average()

# %%
target.plot_topomap();
# Out:
# <MNEFigure size 540x158.4 with 5 Axes>
